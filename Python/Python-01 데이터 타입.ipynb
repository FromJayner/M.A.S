# %% [markdown]
# 안녕하세요

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# 첫번째 파이썬 코드를 실행했습니다.

# %%
# 변수 규칙 1
a = 1
b = 2

student_count = 100
print(a * b, student_count)
# Out:
# 2 100

# %%
#대소문자를 구별한다.
friend = 1
Friend = 10
print(friend)
# Out:
# 1

# %%
#예약어는 사용할 수 없다.

for = 1
# Out:
#   File "<ipython-input-4-d5744cb29876>", line 3
#     for = 1
#         ^
# SyntaxError: invalid syntax

# %%
# 숫자형
year = 2023
month = 4
print(year, month)

# %%
year = 2023
print(type(year))
year = '이천이십삼년'
print(type(year))

# %%
#8진수
#정수 앞에 0o를 붙이면 8진수가 된다.
#정수 앞에 0b를 붙이면 2진수
#정수 앞에 0x를 붙이면 16진수
print(0o10)

# %%
# 다음은 10진수를 받아서 각 진수로 변환하는 방법 (결과가 문자형)
print(type(oct(38)))

# %%
#파이썬의 정수 타입
print(type(1))
print(type(2**31))

# %%
print(x.i)

# %%
#원의 넓이와 삼각형 넓이 구하기
r = 2
circle_area=(r**2)*3.14
print(circle_area)

x = 3
t = 4
triangle_area = x * t / 2
print(triangle_area)

# %%
print('hello wowrld')
print("hello wowrld")
print("welcome to 'python world'")

# %%
print('''
항상 태양을 바라보아라
그리하면 너는 그림자를 볼 수 없을 것이다.

              -헬렌켈러
''')

# %%
print('\t탭 \n다음줄')

# %%
print('py' 'thon')
print('py' + 'thon')

# %%
print('py' * 3)

# %%
a= 'python'

# %%
print(a[0])
print(a[0+1])

# %%
print(str(3.14))
print(int('49'))
print(float(23))
