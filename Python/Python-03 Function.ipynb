# %%
def Times(a, b):
  result = a * b
  return result

# %%
print(Times)
# Out:
# <function Times at 0x7f2edc542b80>

# %%
print(Times(10,20))
# Out:
# 200

# %%
print(id(Times))
# Out:
# 139839241726848

# %%
myTimes = Times
print(myTimes(10,20))
# Out:
# 200

# %%
print(id(myTimes))
# Out:
# 139839241726848

# %%
a = 10
b = 20
def sum1(x, y):
  return x+y

# %%
print(sum1(a,b))
# Out:
# 30

# %%
x = 10
def sum2(x, y):
 x= 1
 return x, y

 sum2(x, 20)

# %%
print(sum2(x, 20))
print(x)
# Out:
# (1, 20)
# 10

# %%
def connectURL(protocol, server, port):
  address = protocol + '://' + server  + ':' + port
  return address
  print(connectURL('http', 'naver.com', '8080'))

# %%
def test(*args):
  print(type(args))
  print(args)

test(1,2,3,4,5)
test(1,2,3)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)
# <class 'tuple'>
# (1, 2, 3)
