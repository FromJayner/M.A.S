# %%
# !pip install azure-storage-file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from azure.storage.file import FileService
file_service = FileService(account_name='labuser1storage2',account_key='oR2DcNyvRRHxb56hroyHB2E2rqXMdjq9NJQMLyYNq9J7zenbBHuzWdQSXVcB5Z5p1QVUOsheDnWC+AStyROs1Q==')

# %%
file_service.create_share('myshare')
# Out:
# True

# %%
file_service.create_directory('myshare','sampledir')
# Out:
# True

# %%
from azure.storage.file import ContentSettings
file_service.create_file_from_path(
    'myshare',
    'sampledir',
    'myfile.jpeg',
    'IU.jpeg'
)

# %%
# directory 내용의 확인 
generator = file_service.list_directories_and_files('myshare')
for file_or_dir in generator:
  print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
# 파일을 가져오는 코드
file_service.get_file_to_path('myshare',None,'myfile','IU_DOWNLOAD.jpeg')

# %%
# snapshot
metadata = {'foo':'bar'}
snapshot = file_service.snapshot_share('myshare',metadata=metadata)

# %%
share = list(file_service.list_shares(include_snapshots=True))

# %%
directories_and_file = list(file_service.list_directories_and_files('myshare',snapshot='2023-04-20T05:48:07.0000000Z'))
for file_or_dir in directories_and_file:
  print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
file_service.delete_share('myshare',snapshot='2023-04-20T05:48:12.0000000Z')
# Out:
# True

# %%
file_service.delete_file('myshare',None,'myfile')
# Out:
# ERROR:azure.storage.common.storageclient:Client-Request-ID=259db024-df44-11ed-9c50-0242ac1c000c Retry policy did not allow for a retry: Server-Timestamp=Thu, 20 Apr 2023 06:25:29 GMT, Server-Request-ID=62b96034-e01a-00a5-7f50-73f710000000, HTTP status code=404, Exception=The specified resource does not exist. ErrorCode: ResourceNotFound<?xml version="1.0" encoding="utf-8"?><Error><Code>ResourceNotFound</Code><Message>The specified resource does not exist.RequestId:62b96034-e01a-00a5-7f50-73f710000000Time:2023-04-20T06:25:30.0560397Z</Message></Error>.
# ---------------------------------------------------------------------------
# AzureMissingResourceHttpError             Traceback (most recent call last)
# <ipython-input-32-ba18a0c6c3ad> in <cell line: 1>()
# ----> 1 file_service.delete_file('myshare',None,'myfile')
#
# /usr/local/lib/python3.9/dist-packages/azure/storage/file/fileservice.py in delete_file(self, share_name, directory_name, file_name, timeout)
# ...

# %%
file_service.delete_share('myshare')
# Out:
# True
