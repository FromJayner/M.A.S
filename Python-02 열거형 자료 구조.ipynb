# %%
colors = [ 'red', 'green', 'gold']
print(colors)
print(type(colors))
# Out:
# ['red', 'green', 'gold']
# <class 'list'>

# %%
colors.append('blue')
print(colors)
# Out:
# ['red', 'green', 'gold', 'blue']

# %%
colors.insert(1, 'black')
print(colors)
# Out:
# ['red', 'black', 'green', 'gold', 'blue']

# %%
colors.extend(['white','gray'])
print(colors)
# Out:
# ['red', 'black', 'green', 'gold', 'blue', 'white', 'gray']

# %%
colors += ['red']
print(colors)
# Out:
# ['red', 'black', 'green', 'gold', 'blue', 'white', 'gray', 'red']

# %%
print(colors.index('red'))
print(colors.index('red', 1))
print(colors.count('red'))
# Out:
# 0
# 7
# 2

# %%
colors.pop()
# Out:
# 'red'

# %%
colors.pop()
# Out:
# 'blue'

# %%
colors.pop(1)
# Out:
# 'black'

# %%
print(colors)
# Out:
# ['red', 'green', 'gold']

# %%
colors.remove('gold')
print(colors)
# Out:
# ['red', 'green']

# %%
colors.sort()
print(colors)
colors.reverse()
print(colors)
# Out:
# ['green', 'red']
# ['red', 'green']

# %%
a = {1, 2, 3}
b = {3, 4, 5}

# %%
print(a, b)
print(type(a))
# Out:
# {1, 2, 3} {3, 4, 5}
# <class 'set'>

# %%
print(a.union(b))
print(a.intersection(b))
# Out:
# {1, 2, 3, 4, 5}
# {3}

# %%
print(a-b)
print(a | b)
print(a&b)
# Out:
# {1, 2}
# {1, 2, 3, 4, 5}
# {3}

# %%
t = (1,2,3)
print(type(t))
# Out:
# <class 'tuple'>

# %%
(a, b) = (1, 2)
print(a, b)
# Out:
# 1 2

# %%
a = 10
b = 20
(a,b) = (b, a)

print(a,b)
# Out:
# 20 10

# %%
a = set((1,2,3))
print(type(a))
b = list(a)
print(type(b))
c = tuple(b)
print(type(c))
d = set(c)
print(type(d))
# Out:
# <class 'set'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>

# %%
a = set((1,2,3))
print(1 in a)
# Out:
# True

# %%
d = dict(a=1, b=2, c=3)
print(d)
print(type(d))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# <class 'dict'>

# %%
color={'apple' : 'red', 'banana' : 'yellow'}
print(color)
# Out:
# {'apple': 'red', 'banana': 'yellow'}

# %%
print(color['apple'])
print(color['cherry'])
# Out:
# red
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-cb49cd99cc27> in <cell line: 2>()
#       1 print(color['apple'])
# ----> 2 print(color['cherry'])
#
# KeyError: 'cherry'

# %%
color['apple']='green'
print(color)
# Out:
# {'apple': 'green', 'banana': 'yellow'}

# %%
print(color.keys())
print(color.values())
print(color.items())
# Out:
# dict_keys(['apple', 'banana'])
# dict_values(['green', 'yellow'])
# dict_items([('apple', 'green'), ('banana', 'yellow')])

# %%
for k in color.keys():
  print(k)
for k in color.keys():
  print(k) 
  for k in color.keys():
  print(k)
# Out:
# apple
# banana

# %%
del color['apple']
print(color)
# Out:
# {'banana': 'yellow'}

# %%
color.clear()
print(color)
# Out:
# {}

# %%
d = {'age': 40.5, 'job':[1,2,3], 'name': {'Kim':2} , 'cho':1 }
print(d)
# Out:
# {'age': 40.5, 'job': [1, 2, 3], 'name': {'Kim': 2}, 'cho': 1}

# %%
isRight = False
print(type(isRight))
# Out:
# <class 'bool'>

# %%
print(1<2)
print(1==2)
print(1!=2)
# Out:
# True
# False
# True

# %%
print(True and False)
print(True & False)
print(True or False)
print(True and False)
print(True and False)
# Out:
# False
# False
# False
# False
# False

# %%
a = [1, 2, 3]
b = a
print(b)
# Out:
# [1, 2, 3]

# %%
a[0]=38
print(a)
print(b)
# Out:
# [38, 2, 3]
# [38, 2, 3]

# %%
a = [1, 2, 3]
b = a[ : ]
a[0] = 38
print(a,b)
# Out:
# [38, 2, 3] [1, 2, 3]

# %%
import copy

a = [1, 2, 3]
b = copy.deepcopy(a)
a[0] = 38
print(a,b)
# Out:
# [38, 2, 3] [1, 2, 3]
